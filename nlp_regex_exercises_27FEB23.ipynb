# %% [markdown]
# # RegEx Exercises
#
# 27 February 2023

# %%
#imports

import pandas as pd
import re
import numpy as np

# %% [markdown]
# ### 1/ Write a function named is_vowel. It should accept a string as input and use a regular expression to determine if the passed string is a vowel. While not explicity mentioned in the lesson, you can treat the result of re.search as a boolean value that indicates whether or not the regular expression matches the given string.

# %%
# function to determine whether there's a vowel in the entered string

def is_vowel(entered_string):
    '''
    this function takes in a string, uses RegEx to determine 
    whether there's a vowel in the entered string, and
    returns a boolean T/F .
    '''
    vowel = bool(re.search(r'[aeiou]', entered_string, re.IGNORECASE))
    
    return vowel

# %%
is_vowel('Entered_strIng')
# Out:
# True

# %% [markdown]
# ### 2/ Write a function named is_valid_username that accepts a string as input. A valid username starts with a lowercase letter, and only consists of lowercase letters, numbers, or the _ character. It should also be no longer than 32 characters. The function should return either True or False depending on whether the passed string is a valid username.

# %%
def is_valid_username(entered_string):
    
    '''this function takes in a username,
    uses RegEx to determine whether there are 
    any characters besides lowercased letters, 
    digits or the '_' character, and returns 
    True if the username is acceptable, and 
    False if it's not.
    '''

    uname = bool(re.search(r'^[a-z][a-z_0-9]{2,32}$', entered_string))

    
    return uname

# %%
is_valid_username('entereeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeeed_str2')
# Out:
# False

# %%
is_valid_username('entered_str2')
# Out:
# True

# %%
def is_valid_username(entered_string):
    
    uname = bool(re.search(r'^[a-z][a-z_0-9]{2,32}$', entered_string))
    if unname:
            print('false')
    else:
            print('true')

            
            
 # starts w lowercase, 
# only lowercase,
    # numbers, 
    # _ 
    # in username
    
# boolean

# %% [markdown]
# ### 3/ Write a regular expression to capture phone numbers. It should match all of the following:
#
# (210) 867 5309
# +1 210.867.5309
# 867-5309
# 210-867-5309

# %%
re.search(r'\d[{1}|{3}]', '724-7147576259')
# Out:
# <re.Match object; span=(4, 6), match='71'>

# %%
re.search(r'\d{1}.*|\d{3}', '210-867-5309')
# Out:
# <re.Match object; span=(0, 12), match='210-867-5309'>

# %%
re.search(r'\d{1}.*|\d{3}', '867-5309')
# Out:
# <re.Match object; span=(0, 8), match='867-5309'>

# %%
re.search(r'\d{1}.*|\+.*\d', '+1 210.867.5309')
# Out:
# <re.Match object; span=(0, 15), match='+1 210.867.5309'>

# %%
re.search(r'\(.*|\d{1}.*', '(210) 867 5309')
# Out:
# <re.Match object; span=(0, 14), match='(210) 867 5309'>

# %%
re.search(r'\d{1}.*|\(.*', '(210) 867 5309')
# Out:
# <re.Match object; span=(0, 14), match='(210) 867 5309'>

# %%
no1 = '(210) 867 5309'
no2 = '+1 210.867.5309'
no3 = '867-5309'
no4 = '210-867-5309'

# %%
re.search(f'^(\+?)(\d?)-?', no2)
# Out:
# <re.Match object; span=(0, 2), match='+1'>

# %%
# in-class example

#all the numbers
regexp = r'.*\d{,3}.*\d{3}.*\d{4}'
subject = '(210) 867 5309'

re.findall(regexp, subject)

# %%
# in-class example

def is_phone_number(x):
    '''
    This function takes in a phone number,
    requires exactly 3 digits, exactly 3 digits, and finally exactly 4 digits. 
    If it does these things, returns true
    otherwise returns false.
    '''
    if re.search(r'.*\d{,3}.*\d{3}.*\d{4}', x):
        return True
    else:
        return False

# %%
# in-class example, III

def is_phone_number2(string):
    phone_number_re = "(\+?\d+)?.?(\(?\d{3}\)?)?.?\d{3}.?\d{4}"
    
    return bool(re.search(phone_number_re, string))

# %%
# in-class example, II

numbers = ['(210) 867 5309',
'+1 210.867.5309',
'867-5309',
'210-867-5309',
'abc']

regexp = r'.*?\d+\D*?\d+.\d+$'

for number in numbers:
    print(re.findall(regexp, number))

# %% [markdown]
# ### 4/ Use regular expressions to convert the dates below to the standardized year-month-day format.
#
# 02/04/19
# 02/05/19
# 02/06/19
# 02/07/19
# 02/08/19
# 02/09/19
# 02/10/19

# %%
re.search(r'\d\d?.\d\d?.\d\d?.*', '02/04/1900')
# Out:
# <re.Match object; span=(0, 10), match='02/04/1900'>

# %%
# cf o'reilly regex cookbook

# and me trying things out 

re.search(r'(1[0-2]|0[1-9])(\-|\.|\/)(3[01]|[12][0-9]|0[1-9])(\-|\.|\/)[0-9]{2}.*', '02/04/1900')
# Out:
# <re.Match object; span=(0, 10), match='02/04/1900'>

# %%
# lesson example 
re.sub(r'.(.).', r'\1', 'abc')
# Out:
# 'b'

# %%
# lesson example 
re.sub(r'(.)(.)(.)', r'\3\2\1', 'abc')
# Out:
# 'cba'

# %%
# me trying things out 

re.sub(r'(.)(.)(.)(.)',  r'\3\1\2\4','name')
# Out:
# 'mnae'

# %%
# me trying things out 

s = re.sub(r'\/',' ','02/04/1956')

s
# Out:
# '02 04 1956'

# %%
# me trying things out 

re.sub(r'(..)/(..)/(....)',  r'\3/\1/\2','02/04/1956')
# Out:
# '1956/02/04'

# %% [markdown]
# ### 5/ Write a regex to extract the various parts of these logfile lines:
#
# cf https://www.oreilly.com/library/view/perl-cookbook/1565922433/ch20s13.html

# %%
# logfile lines
logs = '''

GET /api/v1/sales?page=86 [16/Apr/2019:193452+0000] HTTP/1.1 {200} 510348 "python-requests/2.21.0" 97.105.19.58
POST /users_accounts/file-upload [16/Apr/2019:193452+0000] HTTP/1.1 {201} 42 "User-Agent: Mozilla/5.0 (X11; Fedora; Fedora; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/73.0.3683.86 Safari/537.36" 97.105.19.58
GET /api/v1/items?page=3 [16/Apr/2019:193453+0000] HTTP/1.1 {429} 3561 "python-requests/2.21.0" 97.105.19.58
'''
print(logs)
# Out:
# GET /api/v1/sales?page=86 [16/Apr/2019:193452+0000] HTTP/1.1 {200} 510348 "python-requests/2.21.0" 97.105.19.58
# POST /users_accounts/file-upload [16/Apr/2019:193452+0000] HTTP/1.1 {201} 42 "User-Agent: Mozilla/5.0 (X11; Fedora; Fedora; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/73.0.3683.86 Safari/537.36" 97.105.19.58
# GET /api/v1/items?page=3 [16/Apr/2019:193453+0000] HTTP/1.1 {429} 3561 "python-requests/2.21.0" 97.105.19.58

# %%
re.findall(r'[A-Z\s/a-z/a-z/a-z\?a-z\=0-9\s\[0-9.A-Z{1}a-z/0-9{4}\:0-9{5}\:0-9{4}\s]', logs)
# Out:
# ['\n',
#  '\n',
#  'G',
#  'E',
#  'T',
#  ' ',
#  '/',
#  'a',
#  'p',
#  'i',
#  '/',
#  'v',
#  '1',
#  '/',
#  's',
#  'a',
#  'l',
#  'e',
#  's',
#  '?',
#  'p',
#  'a',
#  'g',
#  'e',
#  '=',
#  '8',
#  '6',
#  ' ',
#  '[',
#  '1',
#  '6',
#  '/',
#  'A',
#  'p',
#  'r',
#  '/',
#  '2',
#  '0',
#  '1',
#  '9',
#  ':',
#  '1',
#  '9',
#  '3',
#  '4',
#  '5',
#  '2',
#  '0',
#  '0',
#  '0',
#  '0',
#  ' ',
#  'H',
#  'T',
#  'T',
#  'P',
#  '/',
#  '1',
#  '.',
#  '1',
#  ' ',
#  '{',
#  '2',
#  '0',
#  '0',
#  '}',
#  ' ',
#  '5',
#  '1',
#  '0',
#  '3',
#  '4',
#  '8',
#  ' ',
#  'p',
#  'y',
#  't',
#  'h',
#  'o',
#  'n',
#  'r',
#  'e',
#  'q',
#  'u',
#  'e',
#  's',
#  't',
#  's',
#  '/',
#  '2',
#  '.',
#  '2',
#  '1',
#  '.',
#  '0',
#  ' ',
#  '9',
#  '7',
#  '.',
#  '1',
#  '0',
#  '5',
#  '.',
#  '1',
#  '9',
#  '.',
#  '5',
#  '8',
#  '\n',
#  'P',
#  'O',
#  'S',
#  'T',
#  ' ',
#  '/',
#  'u',
#  's',
#  'e',
#  'r',
#  's',
#  'a',
#  'c',
#  'c',
#  'o',
# ...

# %%
pattern = re.compile(r'''
(?P<first_name>\w+)?
\.?
(?P<last_name>\w+)? 
\@
(?P<domain>\w+)
\.
(?P<tld>\w+)
''', re.VERBOSE)

# %%
re.findall(r'\D*', logs)
# everhting that's not a digit
# Out:
# ['\n\nGET /api/v',
#  '',
#  '/sales?page=',
#  '',
#  '',
#  ' [',
#  '',
#  '',
#  '/Apr/',
#  '',
#  '',
#  '',
#  '',
#  ':',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '+',
#  '',
#  '',
#  '',
#  '',
#  '] HTTP/',
#  '',
#  '.',
#  '',
#  ' {',
#  '',
#  '',
#  '',
#  '} ',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  ' "python-requests/',
#  '',
#  '.',
#  '',
#  '',
#  '.',
#  '',
#  '" ',
#  '',
#  '',
#  '.',
#  '',
#  '',
#  '',
#  '.',
#  '',
#  '',
#  '.',
#  '',
#  '',
#  '\nPOST /users_accounts/file-upload [',
#  '',
#  '',
#  '/Apr/',
#  '',
#  '',
#  '',
#  '',
#  ':',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '+',
#  '',
#  '',
#  '',
#  '',
#  '] HTTP/',
#  '',
#  '.',
#  '',
#  ' {',
#  '',
#  '',
#  '',
#  '} ',
#  '',
#  '',
#  ' "User-Agent: Mozilla/',
#  '',
#  '.',
#  '',
#  ' (X',
#  '',
#  '',
#  '; Fedora; Fedora; Linux x',
#  '',
#  '',
#  '_',
#  '',
#  '',
#  ') AppleWebKit/',
#  '',
#  '',
#  '',
#  '.',
#  '',
#  '',
# ...

# %%
re.findall(r'\D?.*', logs)
# prints 'logs' with '\n' before every log line
# Out:
# ['\n',
#  '\nGET /api/v1/sales?page=86 [16/Apr/2019:193452+0000] HTTP/1.1 {200} 510348 "python-requests/2.21.0" 97.105.19.58',
#  '\nPOST /users_accounts/file-upload [16/Apr/2019:193452+0000] HTTP/1.1 {201} 42 "User-Agent: Mozilla/5.0 (X11; Fedora; Fedora; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/73.0.3683.86 Safari/537.36" 97.105.19.58',
#  '\nGET /api/v1/items?page=3 [16/Apr/2019:193453+0000] HTTP/1.1 {429} 3561 "python-requests/2.21.0" 97.105.19.58',
#  '\n',
#  '']

# %%
re.findall(r'\w', logs)
# any alphanum and the _
# Out:
# ['G',
#  'E',
#  'T',
#  'a',
#  'p',
#  'i',
#  'v',
#  '1',
#  's',
#  'a',
#  'l',
#  'e',
#  's',
#  'p',
#  'a',
#  'g',
#  'e',
#  '8',
#  '6',
#  '1',
#  '6',
#  'A',
#  'p',
#  'r',
#  '2',
#  '0',
#  '1',
#  '9',
#  '1',
#  '9',
#  '3',
#  '4',
#  '5',
#  '2',
#  '0',
#  '0',
#  '0',
#  '0',
#  'H',
#  'T',
#  'T',
#  'P',
#  '1',
#  '1',
#  '2',
#  '0',
#  '0',
#  '5',
#  '1',
#  '0',
#  '3',
#  '4',
#  '8',
#  'p',
#  'y',
#  't',
#  'h',
#  'o',
#  'n',
#  'r',
#  'e',
#  'q',
#  'u',
#  'e',
#  's',
#  't',
#  's',
#  '2',
#  '2',
#  '1',
#  '0',
#  '9',
#  '7',
#  '1',
#  '0',
#  '5',
#  '1',
#  '9',
#  '5',
#  '8',
#  'P',
#  'O',
#  'S',
#  'T',
#  'u',
#  's',
#  'e',
#  'r',
#  's',
#  '_',
#  'a',
#  'c',
#  'c',
#  'o',
#  'u',
#  'n',
#  't',
#  's',
#  'f',
#  'i',
#  'l',
#  'e',
#  'u',
#  'p',
#  'l',
#  'o',
#  'a',
#  'd',
#  '1',
#  '6',
#  'A',
#  'p',
#  'r',
#  '2',
#  '0',
#  '1',
#  '9',
#  '1',
#  '9',
#  '3',
#  '4',
#  '5',
#  '2',
#  '0',
#  '0',
# ...

# %%
# splitting on the spaces or the equal sign

re.split(r'\s|=', logs)
# Out:
# ['',
#  '',
#  'GET',
#  '/api/v1/sales?page',
#  '86',
#  '[16/Apr/2019:193452+0000]',
#  'HTTP/1.1',
#  '{200}',
#  '510348',
#  '"python-requests/2.21.0"',
#  '97.105.19.58',
#  'POST',
#  '/users_accounts/file-upload',
#  '[16/Apr/2019:193452+0000]',
#  'HTTP/1.1',
#  '{201}',
#  '42',
#  '"User-Agent:',
#  'Mozilla/5.0',
#  '(X11;',
#  'Fedora;',
#  'Fedora;',
#  'Linux',
#  'x86_64)',
#  'AppleWebKit/537.36',
#  '(KHTML,',
#  'like',
#  'Gecko)',
#  'Chrome/73.0.3683.86',
#  'Safari/537.36"',
#  '97.105.19.58',
#  'GET',
#  '/api/v1/items?page',
#  '3',
#  '[16/Apr/2019:193453+0000]',
#  'HTTP/1.1',
#  '{429}',
#  '3561',
#  '"python-requests/2.21.0"',
#  '97.105.19.58',
#  '']

# %%
re.findall(r'[a-z\w]?.*', logs)

# same as re.findall(r'[a-z]?.*', logs)
# Out:
# ['',
#  '',
#  'GET /api/v1/sales?page=86 [16/Apr/2019:193452+0000] HTTP/1.1 {200} 510348 "python-requests/2.21.0" 97.105.19.58',
#  '',
#  'POST /users_accounts/file-upload [16/Apr/2019:193452+0000] HTTP/1.1 {201} 42 "User-Agent: Mozilla/5.0 (X11; Fedora; Fedora; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/73.0.3683.86 Safari/537.36" 97.105.19.58',
#  '',
#  'GET /api/v1/items?page=3 [16/Apr/2019:193453+0000] HTTP/1.1 {429} 3561 "python-requests/2.21.0" 97.105.19.58',
#  '',
#  '']

# %%
url_re = r'(https?)://(\w+)\.(\w+)'

re.search(url_re, sentence).groups()


# unpacking


protocol, domaine, tld = re.search(url_re, sentence).groups()

print(f'''
protocol: {protocol}
domain: {domaine}
tld: {tld}
''')




#name inside of pattern

url_re = r'(?P<protocol>https:?)://(?P<domain>\w+)\.(?P<tld>\w+)'
# <named protocol> folleowd by what to capture in capturegroup

# %%
re.findall(r'[(/?.*)(\w+?.*)(\w?)]', logs)
# Out:
# ['G',
#  'E',
#  'T',
#  '/',
#  'a',
#  'p',
#  'i',
#  '/',
#  'v',
#  '1',
#  '/',
#  's',
#  'a',
#  'l',
#  'e',
#  's',
#  '?',
#  'p',
#  'a',
#  'g',
#  'e',
#  '8',
#  '6',
#  '1',
#  '6',
#  '/',
#  'A',
#  'p',
#  'r',
#  '/',
#  '2',
#  '0',
#  '1',
#  '9',
#  '1',
#  '9',
#  '3',
#  '4',
#  '5',
#  '2',
#  '+',
#  '0',
#  '0',
#  '0',
#  '0',
#  'H',
#  'T',
#  'T',
#  'P',
#  '/',
#  '1',
#  '.',
#  '1',
#  '2',
#  '0',
#  '0',
#  '5',
#  '1',
#  '0',
#  '3',
#  '4',
#  '8',
#  'p',
#  'y',
#  't',
#  'h',
#  'o',
#  'n',
#  'r',
#  'e',
#  'q',
#  'u',
#  'e',
#  's',
#  't',
#  's',
#  '/',
#  '2',
#  '.',
#  '2',
#  '1',
#  '.',
#  '0',
#  '9',
#  '7',
#  '.',
#  '1',
#  '0',
#  '5',
#  '.',
#  '1',
#  '9',
#  '.',
#  '5',
#  '8',
#  'P',
#  'O',
#  'S',
#  'T',
#  '/',
#  'u',
#  's',
#  'e',
#  'r',
#  's',
#  '_',
#  'a',
#  'c',
#  'c',
#  'o',
#  'u',
#  'n',
#  't',
#  's',
#  '/',
#  'f',
#  'i',
#  'l',
#  'e',
#  'u',
#  'p',
#  'l',
#  'o',
#  'a',
#  'd',
# ...

# %% [markdown]
# #### Note:
#
# There are multiple parts to this:
#
#     method --> GET
#     path --> api/v1/sales?page=86
#     timestamp --> [16/Apr/2019:193452+0000]
#     http_version --> HTTP/1.1
#     status --> {200}
#     bytes --> 510348
#     user_agent --> "python-requests/2.21.0"
#     ip --> 97.105.19.58
#
#
# We will want to call out each component for this exercise

# %%
# in-class example

logfile_re = r'''
^(?P<method>GET|POST)
\s+
(?P<path>.*?)
\s+
\[(?P<timestamp>.*?)\]
\s+
(?P<http_version>.*?)
\s+
\{(?P<status>\d+)\}
\s+
(?P<bytes>\d+)
\s+
"(?P<user_agent>.*)"
\s+
(?P<ip>.*)$
'''

lines = pd.Series([
    'GET /api/v1/sales?page=86 [16/Apr/2019:193452+0000] HTTP/1.1 {200} 510348 "python-requests/2.21.0" 97.105.19.58',
    'POST /users_accounts/file-upload [16/Apr/2019:193452+0000] HTTP/1.1 {201} 42 "User-Agent: Mozilla/5.0 (X11; Fedora; Fedora; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/73.0.3683.86 Safari/537.36" 97.105.19.58',
    'GET /api/v1/items?page=3 [16/Apr/2019:193453+0000] HTTP/1.1 {429} 3561 "python-requests/2.21.0" 97.105.19.58',
])

lines.str.extract(logfile_re, re.VERBOSE)
